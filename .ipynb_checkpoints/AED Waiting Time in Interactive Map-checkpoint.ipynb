# %%
#Import libraries
import json
from urllib.request import urlopen
import ssl
import requests
import pandas as pd
import folium
import re

# %%
#import AED waiting data json
context = ssl._create_unverified_context()
link = urlopen("http://www.ha.org.hk/opendata/aed/aedwtdata-en.json", context=context)
aedwait_json = json.loads(link.read())

# %%
#Finding related information about waiting data
hospital = []
waitingTime = []
for i in range(len(aedwait_json['waitTime'])):
    hospital.append(aedwait_json['waitTime'][i]['hospName'])
    waitingTime.append(aedwait_json['waitTime'][i]['topWait'])

waitingList = pd.DataFrame({'Hospital':hospital, 'Waiting Time': waitingTime})
updateTime = aedwait_json['updateTime']

# %%
#View data
waitingList
# Out:
#                                     Hospital   Waiting Time
# 0      Alice Ho Miu Ling Nethersole Hospital   Over 2 hours
# 1                     Caritas Medical Centre   Over 2 hours
# 2                         Kwong Wah Hospital   Over 4 hours
# 3                    North District Hospital   Over 6 hours
# 4                      North Lantau Hospital   Over 2 hours
# 5                 Princess Margaret Hospital   Over 3 hours
# 6                            Pok Oi Hospital   Over 2 hours
# 7                   Prince of Wales Hospital   Over 8 hours
# 8   Pamela Youde Nethersole Eastern Hospital   Over 2 hours
# 9                   Queen Elizabeth Hospital   Over 2 hours
# 10                       Queen Mary Hospital   Over 3 hours
# 11                        Ruttonjee Hospital   Over 3 hours
# 12                          St John Hospital  Around 1 hour
# 13                    Tseung Kwan O Hospital   Over 3 hours
# 14                         Tuen Mun Hospital   Over 8 hours
# 15                     Tin Shui Wai Hospital   Over 3 hours
# 16                 United Christian Hospital   Over 8 hours
# 17                         Yan Chai Hospital   Over 2 hours

# %%
#Import Geospatial data of hospitals
link2 = urlopen("https://www.ha.org.hk/opendata/facility-hosp.json", context=context)
hospitalLoc = pd.read_json(link2)

# %%
#Join both sources
hospitalLoc['institution_eng'] = hospitalLoc['institution_eng'].str.replace('.', '')
full_list = hospitalLoc[['institution_eng', 'latitude', 'longitude', 'address_eng']].merge(waitingList, left_on = 'institution_eng', right_on = 'Hospital')
full_list.drop(labels = 'institution_eng', axis=1, inplace=True)

# %%
#View combined data
full_list
# Out:
#      latitude  longitude                                        address_eng
# 0   22.269180  114.23643                       3 Lok Man Road, Chai Wan, HK  \
# 1   22.275909  114.17529                266 Queen's Road East, Wan Chai, HK
# 2   22.208059  114.03151   Cheung Chau Hospital Road, Tung Wan, Cheung Chau
# 3   22.270400  114.13117                              102 Pokfulam Road, HK
# 4   22.315174  114.17244                              25 Waterloo Road, KLN
# 5   22.308860  114.17519                             30 Gascoigne Road, KLN
# 6   22.317964  114.27021        No. 2 Po Ning Lane, Hang Hau, Tseung Kwan O
# 7   22.322291  114.22790                  130 Hip Wo Street, Kwun Tong, KLN
# 8   22.340629  114.15231            111 Wing Hong Street, Sham Shui Po, KLN
# 9   22.282571  113.93914        8 Chung Yan Road, Tung Chung, Lantau Island
# 10  22.340057  114.13470  2-10 Princess Margaret Hospital Road, Lai Chi ...
# 11  22.369548  114.11956                7-11 Yan Chai Street, Tsuen Wan, NT
# 12  22.458696  114.17479                       11 Chuen On Road, Tai Po, NT
# 13  22.496832  114.12456                     9 Po Kin Road, Sheung Shui, NT
# 14  22.379939  114.20129                30-32 Ngan Shing Street, Shatin, NT
# 15  22.445230  114.04159                              Au Tau, Yuen Long, NT
# 16  22.458704  113.99585                11 Tin Tan Street, Tin Shui Wai, NT
# 17  22.407080  113.97621             23 Tsing Chung Koon Road, Tuen Mun, NT
#
#                                     Hospital   Waiting Time
# 0   Pamela Youde Nethersole Eastern Hospital   Over 2 hours
# 1                         Ruttonjee Hospital   Over 3 hours
# 2                           St John Hospital  Around 1 hour
# 3                        Queen Mary Hospital   Over 3 hours
# 4                         Kwong Wah Hospital   Over 4 hours
# 5                   Queen Elizabeth Hospital   Over 2 hours
# 6                     Tseung Kwan O Hospital   Over 3 hours
# 7                  United Christian Hospital   Over 8 hours
# 8                     Caritas Medical Centre   Over 2 hours
# 9                      North Lantau Hospital   Over 2 hours
# 10                Princess Margaret Hospital   Over 3 hours
# 11                         Yan Chai Hospital   Over 2 hours
# 12     Alice Ho Miu Ling Nethersole Hospital   Over 2 hours
# 13                   North District Hospital   Over 6 hours
# 14                  Prince of Wales Hospital   Over 8 hours
# 15                           Pok Oi Hospital   Over 2 hours
# 16                     Tin Shui Wai Hospital   Over 3 hours
# 17                         Tuen Mun Hospital   Over 8 hours

# %%
# Import GOPC list
link3 = urlopen("https://www.ha.org.hk/opendata/facility-gop.json", context=context)
gopcLoc = pd.read_json(link3)

# %%
gopcList = gopcLoc[['institution_eng', 'latitude', 'longitude', 'address_eng']]

# %%
#Colouring of dots by time. 
#Since it is normally expected non-urgent cases will be consulted in 4-6 hours, it will be cut offs of colours.
def grading(string):
    try:
        weight = int(re.findall(r'\d', string)[0])
    except:
        return 'gray'
    if weight < 8 :
        return 'blue'
    else:
        return 'red'

# %%
#Generate a Hong Kong map using folium
hkmap = folium.Map(width=1000,height=480, location=[22.36, 114.15], zoom_start=11, tiles="Cartodb Positron")

# %%
#Putting dots and titles

#Add dots to AEDs
r = folium.FeatureGroup(name= '<span style="color:red">AED, waiting time more than 8 hours</span>')
b = folium.FeatureGroup(name='<span style="color:blue">AED, waiting time less than 8 hours</span>')
for i in full_list.iterrows():
    j = i[1]
    color=grading(j['Waiting Time'])
    circle = folium.CircleMarker(
    location=[j['latitude'], j['longitude']],
    radius=10,
    color=color,
    stroke=True,
    fill=True,
    fill_opacity=0.3,
    opacity=1,
    popup = folium.map.Popup(html = '{} <br> {}'.format(j['Hospital'], j['address_eng']), max_width = 200),
    tooltip='{}, {}'.format(j['Hospital'], j['Waiting Time']),
)
    if color == 'blue':
        b.add_child(circle)
    elif color == 'red':
        r.add_child(circle)
    else:
        circle.add_to(hkmap)
b.add_to(hkmap)
r.add_to(hkmap)

    
#Add dots to GOPC
g = folium.FeatureGroup(name='<span style="color:green">General Outpatient Clinics</span>')
for i in gopcList.iterrows():
    j = i[1]
    circle = folium.CircleMarker(
    location=[j['latitude'], j['longitude']],
    radius=3,
    color='green',
    stroke=False,
    fill=True,
    fill_opacity=0.8,
    opacity=1,
    popup = folium.map.Popup(html = '{} <br> {}'.format(j['institution_eng'], j['address_eng']), max_width = 200),
    tooltip='{}'.format(j['institution_eng'])
)
    g.add_child(circle)
g.add_to(hkmap)
    

#Add Title
loc = 'AED Longest Waiting Time as at {}'.format(updateTime)
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   
hkmap.get_root().html.add_child(folium.Element(title_html))

#
#hkmap.add_child(r)
#hkmap.add_child(b)

folium.map.LayerControl('topleft', collapsed= False).add_to(hkmap)

# %%
#Show the map
hkmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7ea23a10bb971bb46948e35e87b8cf1 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 480.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;AED Longest Waiting Time as at 26/9/2023 1:00pm&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7ea23a10bb971bb46948e35e87b8cf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7ea23a10bb971bb46948e35e87b8cf1 = L.map(
#                 &quot;map_b7ea23a10bb971bb46948e35e87b8cf1&quot;,
#                 {
#                     center: [22.36, 114.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f8b64394df4007e01e16a8bee72bda = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7ea23a10bb971bb46948e35e87b8cf1);
#
#
#             var feature_group_e8fea96ad4cb606e0f9aea6f22a4e71e = L.featureGroup(
#                 {}
#             ).addTo(map_b7ea23a10bb971bb46948e35e87b8cf1);
#
#
#             var circle_marker_3cde521f497e31fb5f92fcbea06b85f5 = L.circleMarker(
#                 [22.26918, 114.23643],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e8fea96ad4cb606e0f9aea6f22a4e71e);
#
#
#         var popup_2f55d23ee8434680eb594821f0e39729 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_1f888f5b2398228bb19c8a1279e94158 = $(`&lt;div id=&quot;html_1f888f5b2398228bb19c8a1279e94158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pamela Youde Nethersole Eastern Hospital &lt;br&gt; 3 Lok Man Road, Chai Wan, HK&lt;/div&gt;`)[0];
#                 popup_2f55d23ee8434680eb594821f0e39729.setContent(html_1f888f5b2398228bb19c8a1279e94158);
#
#
#
#         circle_marker_3cde521f497e31fb5f92fcbea06b85f5.bindPopup(popup_2f55d23ee8434680eb594821f0e39729)
#         ;
#
#
#
#
#             circle_marker_3cde521f497e31fb5f92fcbea06b85f5.bindTooltip(
#                 `&lt;div&gt;
#                      Pamela Youde Nethersole Eastern Hospital, Over 2 hours
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d461f535255325329b1269df97471180 = L.circleMarker(
#                 [22.275909, 114.17529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e8fea96ad4cb606e0f9aea6f22a4e71e);
#
#
#         var popup_1a2ee771d490b2eed9926de1b6759de6 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_266f634c933a973ff9138825df8d363a = $(`&lt;div id=&quot;html_266f634c933a973ff9138825df8d363a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ruttonjee Hospital &lt;br&gt; 266 Queen&#x27;s Road East, Wan Chai, HK&lt;/div&gt;`)[0];
#                 popup_1a2ee771d490b2eed9926de1b6759de6.setContent(html_266f634c933a973ff9138825df8d363a);
#
#
#
#         circle_marker_d461f535255325329b1269df97471180.bindPopup(popup_1a2ee771d490b2eed9926de1b6759de6)
#         ;
#
#
#
#
#             circle_marker_d461f535255325329b1269df97471180.bindTooltip(
#                 `&lt;div&gt;
#                      Ruttonjee Hospital, Over 3 hours
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_1dc12214ec8a3c5f2935688fb334fef4 = L.circleMarker(
#                 [22.208059, 114.03151],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&q
